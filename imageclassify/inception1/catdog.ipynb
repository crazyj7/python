# %% [markdown]
# '''
# Classify Cat and Dog.
# '''

# %% [markdown]
# Use inception.

# %%
from IPython.display import Image, display
Image('07_inception_flowchart.png')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import os

# %%
import inception

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
# download inception model
inception.maybe_download()
# Out:
# Downloading Inception v3 Model ...
# - Download progress: 27.6%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# - Download progress: 67.6%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# - Download progress: 100.0%
# Download finished. Extracting files.
# Done.

# %%
# load model 
model = inception.Inception()
# Out:
# WARNING:tensorflow:From /media/storage/psychic/hub/python/imageclassify/inception1/inception.py:276: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.

# %%
def classify(image_path):
    # Display the image.
    display(Image(image_path))

    # Use the Inception model to classify the image.
    pred = model.classify(image_path=image_path)

    # Print the scores and names for the top-10 predictions.
    model.print_scores(pred=pred, k=10, only_first_name=True)

# %%
image_path = os.path.join(inception.data_dir, 'cropped_panda.jpg')
classify(image_path)
# Out:
# 89.11% : giant panda
#  0.78% : indri
#  0.30% : lesser panda
#  0.15% : custard apple
#  0.12% : earthstar
#  0.09% : sea urchin
#  0.05% : forklift
#  0.05% : digital watch
#  0.05% : gibbon
#  0.05% : go-kart

# %%
def plot_resized_image(image_path):
    # Get the resized image from the Inception model.
    resized_image = model.get_resized_image(image_path=image_path)

    # Plot the image.
    plt.imshow(resized_image, interpolation='nearest')
    
    # Ensure that the plot is shown.
    plt.show()

# %% [markdown]
# ## Download Images....
# Chrome. app ; Fatkun Batch Download Image
